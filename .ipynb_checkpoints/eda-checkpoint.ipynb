# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
columns = ['id_json', 'label', 'statement', 'subject', 
 'speaker', 'speaker_job', 'state', 'party', 
 'barely_true_counts', 'false_counts', 'half_true_counts',
 'mostly_true_counts', 'pants_on_fire_counts', 'context', 'justification']

# %%
train = pd.read_csv('dataset/train2.tsv', sep='\t', header=None, index_col=0, names=columns)
val = pd.read_csv('dataset/val2.tsv', sep='\t', header=None, index_col=0, names=columns)
test = pd.read_csv('dataset/test2.tsv', sep='\t', header=None, index_col=0, names=columns)

# %%
train.shape, val.shape, test.shape
# Out:
# ((10242, 15), (1284, 15), (1267, 15))

# %%
df_nans = pd.DataFrame(train.isnull().sum(), columns=['train_nan']).join(
    pd.DataFrame(val.isnull().sum(), columns=['val_nan']).join(
        pd.DataFrame(test.isnull().sum(), columns=['test_nan'])
    )
)

# %%
df_nans
# Out:
#                       train_nan  val_nan  test_nan
# id_json                       2        0         0
# label                         2        0         0
# statement                     2        0         0
# subject                       4        0         0
# speaker                       4        0         0
# speaker_job                2899      345       325
# state                      2210      279       262
# party                         4        0         0
# barely_true_counts            4        0         0
# false_counts                  4        0         0
# half_true_counts              4        0         0
# mostly_true_counts            4        0         0
# pants_on_fire_counts          4        0         0
# context                     104       12        17
# justification                88        4         9

# %%
train[train.party.isnull()]
# Out:
#           id_json  label                                          statement  \
# 2154.0   638.json  false  The fact is that although we have had a presid...
# NaN           NaN    NaN                                                NaN
# 9404.0  1626.json  false  Joe, I keep hearing you every morning talking ...
# NaN           NaN    NaN                                                NaN
#
#        subject speaker speaker_job state party  barely_true_counts  \
# 2154.0     NaN     NaN         NaN   NaN   NaN                 NaN
# NaN        NaN     NaN         NaN   NaN   NaN                 NaN
# 9404.0     NaN     NaN         NaN   NaN   NaN                 NaN
# NaN        NaN     NaN         NaN   NaN   NaN                 NaN
#
#         false_counts  half_true_counts  mostly_true_counts  \
# 2154.0           NaN               NaN                 NaN
# NaN              NaN               NaN                 NaN
# 9404.0           NaN               NaN                 NaN
# NaN              NaN               NaN                 NaN
#
#         pants_on_fire_counts context justification
# 2154.0                   NaN     NaN           NaN
# NaN                      NaN     NaN           NaN
# 9404.0                   NaN     NaN           NaN
# NaN                      NaN     NaN           NaN

# %% [markdown]
# Удаляю строчки в train с пустыми statement и party

# %%
train.dropna(subset=['statement', 'party'], inplace=True)

# %%
df_nans = pd.DataFrame(train.isnull().sum(), columns=['train_nan']).join(
    pd.DataFrame(val.isnull().sum(), columns=['val_nan']).join(
        pd.DataFrame(test.isnull().sum(), columns=['test_nan'])
    )
)

# %%
df_nans
# Out:
#                       train_nan  val_nan  test_nan
# id_json                       0        0         0
# label                         0        0         0
# statement                     0        0         0
# subject                       0        0         0
# speaker                       0        0         0
# speaker_job                2895      345       325
# state                      2206      279       262
# party                         0        0         0
# barely_true_counts            0        0         0
# false_counts                  0        0         0
# half_true_counts              0        0         0
# mostly_true_counts            0        0         0
# pants_on_fire_counts          0        0         0
# context                     100       12        17
# justification                84        4         9

# %%
# Заполняю пропуски в speaker_job новым значением
train.speaker_job.fillna('noJobInfo', inplace=True)
val.speaker_job.fillna('noJobInfo', inplace=True)
test.speaker_job.fillna('noJobInfo', inplace=True)

# Заполняю пропуски в state новым значением
train.state.fillna('noStateInfo', inplace=True)
val.state.fillna('noStateInfo', inplace=True)
test.state.fillna('noStateInfo', inplace=True)

# Заполняю пропуски в context пустым значением
train.context.fillna('noContextInfo', inplace=True)
val.context.fillna('noContextInfo', inplace=True)
test.context.fillna('noContextInfo', inplace=True)

# Заполняю пропуски в justification пустым значением
train.justification.fillna('noJustificationInfo', inplace=True)
val.justification.fillna('noJustificationInfo', inplace=True)
test.justification.fillna('noJustificationInfo', inplace=True)

# %%
true_labels = ['half-true', 'mostly-true', 'true']

# %% [markdown]
# Делаю таргет для бинарной классификации

# %%
train['is_fake'] = train.label.apply(lambda x: 1 if x not in true_labels else 0)
val['is_fake'] = val.label.apply(lambda x: 1 if x not in true_labels else 0)
test['is_fake'] = test.label.apply(lambda x: 1 if x not in true_labels else 0)

# %%
train['data_type'] = 'train'
val['data_type'] = 'val'
test['data_type'] = 'test'

# %%
data = pd.concat([train, val, test], ignore_index=True)

# %% [markdown]
# ## Распределения признаков

# %% [markdown]
# * **Разбиение на train, val, test отличается несильно**
# * **Баланс классов более-менее стабилизирован. Но класс с фейковыми новостями меньше**

# %%
for col in ['label', 'is_fake', 'subject', 'speaker', 'speaker_job', 'state', 'party']:
    f = plt.figure(figsize=(20, 7))
    top_10 = 'TOP 10' if data[col].nunique() > 10 else ''
    plt.title(f'"{col}" Distribution {top_10}')
    (data[col]
     .groupby(data['data_type'])
     .value_counts(normalize=True)
     .groupby('data_type')
     .head(10)
     .rename('proportion')
     .reset_index()
     .pipe((sns.barplot, "data"), x=col, y='proportion', hue='data_type'))
    plt.show()
    f.savefig(f"media/{col}_1.pdf", bbox_inches='tight')

# %%
cat_cols = ['subject', 'speaker', 'speaker_job', 'state', 'party']

# %% [markdown]
# Уникальное количество категорий

# %%
data[cat_cols].nunique()
# Out:
# subject        4534
# speaker        3309
# speaker_job    1356
# state            86
# party            24
# dtype: int64

# %% [markdown]
# * **subject** представляет собой перечисление топиков новости через запятую. Как кодировть? Эмбеддинги?

# %%
data.subject.iloc[:20]
# Out:
# 0                                      abortion
# 1            energy,history,job-accomplishments
# 2                                foreign-policy
# 3                                   health-care
# 4                                  economy,jobs
# 5                                     education
# 6                          candidates-biography
# 7                                        ethics
# 8                                          jobs
# 9     energy,message-machine-2014,voting-record
# 10                                    elections
# 11      economy,jobs,new-hampshire-2012,poverty
# 12                         history,state-budget
# 13           economy,federal-budget,health-care
# 14                                  health-care
# 15                                    elections
# 16                               federal-budget
# 17                               federal-budget
# 18    financial-regulation,foreign-policy,water
# 19                bankruptcy,economy,population
# Name: subject, dtype: object

# %% [markdown]
# * **speaker** - Очень много спикеров, у которых мало новостных заголовков в данных. Кодировать one-hot? Отобрать топ спикеров? Нет смысла вводить отдельный признак для спикера, у которого всего 2 новости в данных (например)

# %%
plt.figure(figsize=(18, 4))
plt.title('Распределение количества новостей по спикерам')
sns.boxplot(x=data.speaker.value_counts())
plt.show()

# %%
np.percentile(data.speaker.value_counts().values, 50)
# Out:
# 1.0

# %%
np.percentile(data.speaker.value_counts().values, 90)
# Out:
# 6.0

# %%
np.percentile(data.speaker.value_counts().values, 95)
# Out:
# 11.0

# %% [markdown]
# * **speaker_job** - Много уникальных должностей. Эмбеддинги?

# %% [markdown]
# * **state** - много дубликатов в данных. Например, Washington, D.C. и Washington

# %%
data.state = data.state.apply(lambda x: x.strip())

# %% [markdown]
# * **context** - бывает очень подробное описание. Нужно строить эмбеддинги

# %% [markdown]
# **Может соединить признаки в одно предложение?**

# %% [markdown]
# **Нужно из признаков с историей новостей удалить текущий таргет, чтобы не было утечки!**

# %%
targets = ['label', 'is_fake']

# %% [markdown]
# ## Распределение таргета по категориям

# %%
for col in cat_cols:
    for target in targets:
        f = plt.figure(figsize=(20, 7))
        plt.title(f'Feature "{col}" histogram by target "{target}" (TOP 10 categories)')
        (train[col]
         .groupby(train[target])
         .value_counts(normalize=True)
         .groupby(target)
         .head(10)
         .rename('proportion')
         .reset_index()
         .pipe((sns.barplot, "data"), x=col, y='proportion', hue=target))
        plt.xticks(rotation=30)
        plt.show()
        f.savefig(f"media/{targets}_{col}_1.pdf", bbox_inches='tight')

# %% [markdown]
# **Удаляю из истории текущий таргет**

# %%
data[['barely_true_counts', 'false_counts', 'half_true_counts', 'mostly_true_counts', 'pants_on_fire_counts']] = \
data[['barely_true_counts', 'false_counts', 'half_true_counts', 'mostly_true_counts', 'pants_on_fire_counts']].values - \
pd.get_dummies(data.label).drop('true', axis=1).values

# %%
plt.figure(figsize=(18, 6))
plt.title("Распределение длины statement")
statement_len = data.statement.apply(lambda x: len(x.split()))
statement_len.hist(bins=100)
print(f'mean {statement_len.mean()}')
print(f'median {statement_len.median()}')
print(f'99 percentile {np.percentile(statement_len, 99)}')
plt.show()
# Out:
# mean 18.03635937133474
# median 17.0
# 99 percentile 41.0

# %% [markdown]
# **Есть несколько аномальных заголовков**

# %%
statement_len[statement_len > 70]
# Out:
# 1280     479
# 6118     242
# 7549     317
# 12225    442
# 12445    210
# Name: statement, dtype: int64

# %%
anomalies = statement_len[statement_len > 70].index

# %%
data.loc[anomalies[:-1], 'statement'] = data.statement.apply(lambda x: x.split('.')[0]).loc[anomalies[:-1]]

# %%
data.loc[12445, 'statement'] = ''.join(data.loc[12445].statement.split('.')[:5])

# %%
plt.figure(figsize=(18, 6))
plt.title("Распределение длины context")
statement_len = data.context.apply(lambda x: len(x.split()))
statement_len.hist(bins=100)
print(f'mean {statement_len.mean()}')
print(f'median {statement_len.median()}')
print(f'99 percentile {np.percentile(statement_len, 99)}')
plt.show()
# Out:
# mean 4.328876378137462
# median 3.0
# 99 percentile 11.0

# %% [markdown]
# **Есть несколько аномальных заголовков**

# %%
plt.figure(figsize=(18, 6))
plt.title("Распределение длины justification новости")
statement_len = data.justification.apply(lambda x: len(x.split()))
statement_len.hist(bins=100)
print(f'mean {statement_len.mean()}')
print(f'median {statement_len.median()}')
print(f'99 percentile {np.percentile(statement_len, 99)}')
plt.show()
# Out:
# mean 71.16623660958636
# median 66.0
# 99 percentile 181.0

# %%
anomalies = data.loc[statement_len[statement_len > 200].index].justification.apply(lambda x: 1 if '{' in x or '}' in x else 0)

# %%
data.loc[anomalies[anomalies == 1].index, 'justification'] = \
data.loc[anomalies[anomalies == 1].index].justification.apply(lambda x: x.split('{')[0])

# %%
data.loc[:, 'justification'] = data.justification.apply(lambda x: ' '.join(x.split()[:200]))

# %%
data.to_csv('dataset/data_liar_plus.csv', index=False, sep=';')

# %% [markdown]
# ## Примеры

# %% [markdown]
# **true**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[16])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8c0f7368_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >16</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >620.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >true</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >McCain opposed a requirement that the government buy American-made motorcycles. And he said all buy-American provisions were quote 'disgraceful.' </td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >federal-budget</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >barack-obama</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >President</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >Illinois</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >democrat</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >70.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >71.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >160.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >163.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >9.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >a radio ad</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >I firmly object to all 'buy America' restrictions, as they represent gross examples of protectionist trade policy. "He added, "Furthermore, as a fiscal conservative, I want to ensure our government gets the best deal for taxpayers and with a 'buy American' restriction that cannot be guaranteed. "The McCain campaign did not respond to Obama's charge. But his past words say it all.</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8c0f7368_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **mostly-true**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[2])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >324.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >mostly-true</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >Hillary Clinton agrees with John McCain "by voting to give George Bush the benefit of the doubt on Iran."</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >foreign-policy</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >barack-obama</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >President</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >Illinois</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >democrat</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >70.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >71.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >160.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >162.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >9.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >Denver</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >Obama said he would have voted against the amendment if he had been present. So though Clinton may have "agreed" with McCain on the issue, they did not technically vote the same way on it. To say that voting for Kyl-Lieberman is "giving George Bush the benefit of the doubt on Iran" remains a contentious issue. But Obama's main point is that Clinton and McCain were on the same side, and that is correct.</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8ccbf3e4_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **half-true**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[4])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >4</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >9028.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >half-true</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >The economic turnaround started at the end of my term.</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >economy,jobs</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >charlie-crist</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >noJobInfo</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >Florida</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >democrat</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >15.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >9.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >19.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >19.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >2.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >an interview on CNN</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >Crist said that the economic "turnaround started at the end of my term. "During Crists last year in office, Floridas economy experienced notable gains in personal income and industrial production, and more marginal improvements in the unemployment rate and in payroll employment. But GDP didnt grow again until Scott took office. Economists say Crist deserves some credit for the economic turnaround because he accepted federal stimulus dollars, but they add that any state is inevitably buffeted by national and international trends far beyond their control.</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8db8b4fe_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **barely-true**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[17])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >17</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >3863.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >barely-true</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >U.S. Rep. Ron Kind, D-Wis., and his fellow Democrats went on a spending spree and now their credit card is maxed out</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >federal-budget</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >national-republican-congressional-committee</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >noJobInfo</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >noStateInfo</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >republican</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >17.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >9.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >8.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >8.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >a news release</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >And the debt is a result of tax cuts as well as various spending measures, and both Democrats and Republicans supported such measures.</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8e7c8b22_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **false**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[0])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8f3e700c_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >2635.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >false</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >Says the Annies List political group supports third-trimester abortions on demand.</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >abortion</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >dwayne-bohac</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >State representative</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >Texas</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >republican</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >a mailer</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >That's a premise that he fails to back up. Annie's List makes no bones about being comfortable with candidates who oppose further restrictions on late-term abortions. Then again, this year its backing two House candidates who voted for more limits.</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8f3e700c_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **pants-fire**

# %%
df = pd.DataFrame(data.query("data_type == 'train'").iloc[847])
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow0_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow1_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow2_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow3_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow4_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow5_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow6_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow7_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow8_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow9_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow10_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow11_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow12_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow13_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow14_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow15_col0 {
#             text-align:  left;
#         }    #T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow16_col0 {
#             text-align:  left;
#         }</style><table id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >847</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row0" class="row_heading level0 row0" >id_json</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow0_col0" class="data row0 col0" >12570.json</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row1" class="row_heading level0 row1" >label</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow1_col0" class="data row1 col0" >pants-fire</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row2" class="row_heading level0 row2" >statement</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow2_col0" class="data row2 col0" >Says Hillary Clinton has even deleted this record of total support (for the Trans-Pacific Partnership trade agreement) from her book.</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row3" class="row_heading level0 row3" >subject</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow3_col0" class="data row3 col0" >candidates-biography,economy,foreign-policy,history,job-accomplishments,trade</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row4" class="row_heading level0 row4" >speaker</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow4_col0" class="data row4 col0" >donald-trump</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row5" class="row_heading level0 row5" >speaker_job</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow5_col0" class="data row5 col0" >President-Elect</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row6" class="row_heading level0 row6" >state</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow6_col0" class="data row6 col0" >New York</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row7" class="row_heading level0 row7" >party</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow7_col0" class="data row7 col0" >republican</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row8" class="row_heading level0 row8" >barely_true_counts</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow8_col0" class="data row8 col0" >63.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row9" class="row_heading level0 row9" >false_counts</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow9_col0" class="data row9 col0" >114.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row10" class="row_heading level0 row10" >half_true_counts</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow10_col0" class="data row10 col0" >51.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row11" class="row_heading level0 row11" >mostly_true_counts</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow11_col0" class="data row11 col0" >37.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row12" class="row_heading level0 row12" >pants_on_fire_counts</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow12_col0" class="data row12 col0" >60.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row13" class="row_heading level0 row13" >context</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow13_col0" class="data row13 col0" >a speech</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row14" class="row_heading level0 row14" >justification</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow14_col0" class="data row14 col0" >Trump said Hillary Clinton "has even deleted this record of total support (for the Trans-Pacific Partnership trade agreement) from her book. "The paperback removed a small reference to the TPP but the two pages that talked about it and why the agreement was important weren't deleted. The paperback edition continues to have text expressing support for the trade deal.</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row15" class="row_heading level0 row15" >is_fake</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow15_col0" class="data row15 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdlevel0_row16" class="row_heading level0 row16" >data_type</th>
#                         <td id="T_8ffdc59c_a524_11ea_9f7a_dca904807bbdrow16_col0" class="data row16 col0" >train</td>
#             </tr>
#     </tbody></table>
